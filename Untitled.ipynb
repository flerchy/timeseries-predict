# %%
import sklearn

from sklearn.metrics import mean_squared_error

# %%
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib

# %%
ds = pd.read_csv("ds1.csv", names=["1", "2"], skiprows=1)

# %%
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e472cdd6355b> in <module>()
# ----> 1 ds
#
# NameError: name 'ds' is not defined

# %%
ds["1"] = pd.to_datetime(ds["1"], format="%Y-%m")

# %%
ds
# Out:
#              1    2
# 0   1962-01-01  589
# 1   1962-02-01  561
# 2   1962-03-01  640
# 3   1962-04-01  656
# 4   1962-05-01  727
# 5   1962-06-01  697
# 6   1962-07-01  640
# 7   1962-08-01  599
# 8   1962-09-01  568
# 9   1962-10-01  577
# 10  1962-11-01  553
# 11  1962-12-01  582
# 12  1963-01-01  600
# 13  1963-02-01  566
# 14  1963-03-01  653
# 15  1963-04-01  673
# 16  1963-05-01  742
# 17  1963-06-01  716
# 18  1963-07-01  660
# 19  1963-08-01  617
# 20  1963-09-01  583
# 21  1963-10-01  587
# 22  1963-11-01  565
# 23  1963-12-01  598
# 24  1964-01-01  628
# 25  1964-02-01  618
# 26  1964-03-01  688
# 27  1964-04-01  705
# 28  1964-05-01  770
# 29  1964-06-01  736
# ..         ...  ...
# 138 1973-07-01  881
# 139 1973-08-01  837
# 140 1973-09-01  784
# 141 1973-10-01  791
# 142 1973-11-01  760
# 143 1973-12-01  802
# 144 1974-01-01  828
# 145 1974-02-01  778
# 146 1974-03-01  889
# 147 1974-04-01  902
# 148 1974-05-01  969
# 149 1974-06-01  947
# 150 1974-07-01  908
# 151 1974-08-01  867
# 152 1974-09-01  815
# 153 1974-10-01  812
# 154 1974-11-01  773
# 155 1974-12-01  813
# 156 1975-01-01  834
# 157 1975-02-01  782
# 158 1975-03-01  892
# 159 1975-04-01  903
# 160 1975-05-01  966
# 161 1975-06-01  937
# 162 1975-07-01  896
# 163 1975-08-01  858
# 164 1975-09-01  817
# 165 1975-10-01  827
# 166 1975-11-01  797
# 167 1975-12-01  843
#
# [168 rows x 2 columns]

# %%
ds["d"] = (ds["1"] - ds["1"].min())  / np.timedelta64(1,'D')

# %%
ds["d"]
# Out:
# 0         0.0
# 1        31.0
# 2        59.0
# 3        90.0
# 4       120.0
# 5       151.0
# 6       181.0
# 7       212.0
# 8       243.0
# 9       273.0
# 10      304.0
# 11      334.0
# 12      365.0
# 13      396.0
# 14      424.0
# 15      455.0
# 16      485.0
# 17      516.0
# 18      546.0
# 19      577.0
# 20      608.0
# 21      638.0
# 22      669.0
# 23      699.0
# 24      730.0
# 25      761.0
# 26      790.0
# 27      821.0
# 28      851.0
# 29      882.0
#         ...
# 138    4199.0
# 139    4230.0
# 140    4261.0
# 141    4291.0
# 142    4322.0
# 143    4352.0
# 144    4383.0
# 145    4414.0
# 146    4442.0
# 147    4473.0
# 148    4503.0
# 149    4534.0
# 150    4564.0
# 151    4595.0
# 152    4626.0
# 153    4656.0
# 154    4687.0
# 155    4717.0
# 156    4748.0
# 157    4779.0
# 158    4807.0
# 159    4838.0
# 160    4868.0
# 161    4899.0
# 162    4929.0
# 163    4960.0
# 164    4991.0
# 165    5021.0
# 166    5052.0
# 167    5082.0
# Name: d, Length: 168, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor

rng = np.random.RandomState(1)
X = ds["d"]
y = ds["2"]

regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X.reshape(len(X), 1), y)
regr_2.fit(X.reshape(len(X), 1), y)

X_test = ds["d"]
y_1 = regr_1.predict(X_test.reshape(len(X_test), 1))
y_2 = regr_2.predict(X_test.reshape(len(X_test), 1))
plt.figure(figsize=(12, 6))
plt.plot(y)
plt.plot(y_1, color="orange", linewidth=2)
plt.plot(y_2, color="yellowgreen", linewidth=2)
plt.show()
# Out:
# /home/flerchy/.virtualenvs/diploma/lib/python2.7/site-packages/ipykernel_launcher.py:9: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   if __name__ == '__main__':
# /home/flerchy/.virtualenvs/diploma/lib/python2.7/site-packages/ipykernel_launcher.py:10: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   # Remove the CWD from sys.path while we load stuff.
# /home/flerchy/.virtualenvs/diploma/lib/python2.7/site-packages/ipykernel_launcher.py:13: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   del sys.path[0]
# /home/flerchy/.virtualenvs/diploma/lib/python2.7/site-packages/ipykernel_launcher.py:14: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %%
from sklearn.linear_model import LinearRegression

X = ds["d"]  # put your dates in here
y = ds["2"]  # put your kwh in here

model = LinearRegression()
model.fit(X.reshape(len(X), 1), y)

X_predict = X  # put the dates of which you want to predict kwh here
y_predict = model.predict(X_predict.reshape(len(X_predict), 1))
# Out:
# /home/flerchy/.virtualenvs/diploma/lib/python2.7/site-packages/ipykernel_launcher.py:7: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   import sys
# /home/flerchy/.virtualenvs/diploma/lib/python2.7/site-packages/ipykernel_launcher.py:10: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   # Remove the CWD from sys.path while we load stuff.

# %%
plt.figure(figsize=(12, 6))
plt.plot(y[:len(y)])
plt.plot(y_predict)

# %%
from sklearn.isotonic import IsotonicRegression

model =  IsotonicRegression()

X = ds["d"]
y_ = model.fit_transform( X[:len(X)-40], y[:len(y)])

X_predict = ds["d"]  # put the dates of which you want to predict kwh here
y_predict = model.predict(X_predict.reshape(len(X_predict)))
plt.figure(figsize=(12, 6))
plt.plot(y[:len(y)])
plt.plot(y_predict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-362-584653231e74> in <module>()
#       4
#       5 X = ds["d"]
# ----> 6 y_ = model.fit_transform( X[:len(X)-40], y[:len(y)])
#       7
#       8 X_predict = ds["d"]  # put the dates of which you want to predict kwh here
#
# /home/flerchy/.virtualenvs/diploma/local/lib/python2.7/site-packages/sklearn/base.pyc in fit_transform(self, X, y, **fit_params)
#     495         else:
#     496             # fit method of arity 2 (supervised transformation)
# --> 497             return self.fit(X, y, **fit_params).transform(X)
#     498
#     499
#
# /home/flerchy/.virtualenvs/diploma/local/lib/python2.7/site-packages/sklearn/isotonic.pyc in fit(self, X, y, sample_weight)
#     351         # Transform y by running the isotonic regression algorithm and
#     352         # transform X accordingly.
# --> 353         X, y = self._build_y(X, y, sample_weight)
#     354
#     355         # It is necessary to store the non-redundant part of the training set
#
# /home/flerchy/.virtualenvs/diploma/local/lib/python2.7/site-packages/sklearn/isotonic.pyc in _build_y(self, X, y, sample_weight, trim_duplicates)
#     270     def _build_y(self, X, y, sample_weight, trim_duplicates=True):
#     271         """Build the y_ IsotonicRegression."""
# --> 272         check_consistent_length(X, y, sample_weight)
#     273         X, y = [check_array(x, ensure_2d=False) for x in [X, y]]
#     274
#
# /home/flerchy/.virtualenvs/diploma/local/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_consistent_length(*arrays)
#     179     if len(uniques) > 1:
#     180         raise ValueError("Found input variables with inconsistent numbers of"
# --> 181                          " samples: %r" % [int(l) for l in lengths])
#     182
#     183
#
# ValueError: Found input variables with inconsistent numbers of samples: [128, 168]

# %%
p
